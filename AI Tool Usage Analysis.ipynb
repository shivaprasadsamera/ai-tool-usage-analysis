# %% [markdown]
# # **AI Tool Usage by Indian College Students (2025) – Data Analysis**

# %% [markdown]
# ### Step 1: Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Load the Dataset

# %%
# Load the dataset
file_path = "Generative AI in Education.csv"
df = pd.read_csv('/content/Dataset/Students.csv')

# %% [markdown]
# ### Step 3: Inspect Data

# %%
# --- Raw Exploration Section (from your code) ---

print("First 5 rows:")
df.head()
# Out:
# First 5 rows:
#   Student_Name                                      College_Name       Stream  \
# 0        Aarav       Indian Institute of Information Technology   Engineering
# 1       Vivaan   Government Ram Bhajan Rai NES College, Jashpur      Commerce
# 2       Aditya     Dolphin PG Institute of BioMedical & Natural       Science
# 3       Vihaan  Shaheed Rajguru College of Applied Sciences for          Arts
# 4        Arjun                   Roorkee College of Engineering       Science
#
#    Year_of_Study AI_Tools_Used  Daily_Usage_Hours  \
# 0              4        Gemini                0.9
# 1              2       ChatGPT                3.4
# 2              2       Copilot                3.6
# 3              2       Copilot                2.9
# 4              1        Gemini                0.9
#
#                        Use_Cases  Trust_in_AI_Tools  Impact_on_Grades  \
# 0       Assignments, Coding Help                  2                 2
# ...

# %%
print("\nLast 5 rows:")
df.tail()
# Out:
# Last 5 rows:
#      Student_Name                                  College_Name       Stream  \
# 3609       Ishaan           St. Mira's College for Girls, Pune      Commerce
# 3610        Rudra                  Roorkee College of Pharmacy      Pharmacy
# 3611        Dhruv                       Bahona College, Jorhat   Agriculture
# 3612        Kabir  Sree Chitra Thirunal College of Engineering   Engineering
# 3613       Atharv              Poona College of Pharmacy, Pune      Pharmacy
#
#       Year_of_Study     AI_Tools_Used  Daily_Usage_Hours  \
# 3609              1  ChatGPT, Copilot                4.3
# 3610              3           Copilot                3.0
# 3611              3            Gemini                2.7
# 3612              4            Gemini                2.7
# 3613              3           Copilot                0.9
#
#                           Use_Cases  Trust_in_AI_Tools  Impact_on_Grades  \
# ...

# %%
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Student_Name', 'College_Name', 'Stream', 'Year_of_Study',
#        'AI_Tools_Used', 'Daily_Usage_Hours', 'Use_Cases', 'Trust_in_AI_Tools',
#        'Impact_on_Grades', 'Do_Professors_Allow_Use', 'Preferred_AI_Tool',
#        'Awareness_Level', 'Willing_to_Pay_for_Access', 'State', 'Device_Used',
#        'Internet_Access'],
#       dtype='object')

# %%
print("\nShape:", df.shape)
print("\nInfo:")
df.info()
# Out:
# Shape: (3614, 16)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3614 entries, 0 to 3613
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Student_Name               3614 non-null   object
#  1   College_Name               3614 non-null   object
#  2   Stream                     3614 non-null   object
#  3   Year_of_Study              3614 non-null   int64
#  4   AI_Tools_Used              3614 non-null   object
#  5   Daily_Usage_Hours          3614 non-null   float64
#  6   Use_Cases                  3614 non-null   object
#  7   Trust_in_AI_Tools          3614 non-null   int64
#  8   Impact_on_Grades           3614 non-null   int64
#  9   Do_Professors_Allow_Use    3614 non-null   object
#  10  Preferred_AI_Tool          3614 non-null   object
#  11  Awareness_Level            3614 non-null   int64
#  12  Willing_to_Pay_for_Access  3614 non-null   object
# ...

# %%
print("\nStatistical Description:")
df.describe(include='all')
# Out:
# Statistical Description:
#        Student_Name                       College_Name   Stream  \
# count          3614                               3614     3614
# unique           40                               1246       10
# top           Aarav  National Institute of Technology   Science
# freq             91                                231      593
# mean            NaN                                NaN      NaN
# std             NaN                                NaN      NaN
# min             NaN                                NaN      NaN
# 25%             NaN                                NaN      NaN
# 50%             NaN                                NaN      NaN
# 75%             NaN                                NaN      NaN
# max             NaN                                NaN      NaN
#
#         Year_of_Study AI_Tools_Used  Daily_Usage_Hours  \
# count     3614.000000          3614        3614.000000
# unique            NaN             9                NaN
# ...

# %% [markdown]
# ### Step 4: Check Unique Values per Column

# %%
# Count unique values per column
print("\nUnique value counts per column:")
for column in df.columns:
    print(f"{column}: {df[column].nunique()}")
# Out:
# Unique value counts per column:
# Student_Name: 40
# College_Name: 1246
# Stream: 10
# Year_of_Study: 4
# AI_Tools_Used: 9
# Daily_Usage_Hours: 46
# Use_Cases: 333
# Trust_in_AI_Tools: 5
# Impact_on_Grades: 11
# Do_Professors_Allow_Use: 2
# Preferred_AI_Tool: 6
# Awareness_Level: 10
# Willing_to_Pay_for_Access: 2
# State: 34
# Device_Used: 3
# Internet_Access: 3

# %% [markdown]
# ### Step 5: Handle Missing Values

# %%
# Checking nulls and filling with mode
print("\nMissing values before cleaning:")
print(df.isnull().sum())
for col in df.columns:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].mode()[0], inplace=True)
print("\nMissing values after filling:")
df.isnull().sum()
# Out:
# Missing values before cleaning:
# Student_Name                    0
# College_Name                    0
# Stream                          0
# Year_of_Study                   0
# AI_Tools_Used                   0
# Daily_Usage_Hours               0
# Use_Cases                       0
# Trust_in_AI_Tools               0
# Impact_on_Grades                0
# Do_Professors_Allow_Use         0
# Preferred_AI_Tool               0
# Awareness_Level                 0
# Willing_to_Pay_for_Access       0
# State                        1614
# Device_Used                     0
# Internet_Access                 0
# dtype: int64
#
# Missing values after filling:
# Student_Name                 0
# College_Name                 0
# Stream                       0
# Year_of_Study                0
# AI_Tools_Used                0
# Daily_Usage_Hours            0
# Use_Cases                    0
# Trust_in_AI_Tools            0
# Impact_on_Grades             0
# Do_Professors_Allow_Use      0
# ...

# %% [markdown]
# ### Step 6: Visualizations and Insights

# %% [markdown]
# #### 6.1 Distribution by Stream

# %%
# Distribution of Streams
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='Stream', palette='Set2')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2, height + 0.5, int(height),
                ha='center', va='bottom', fontsize=8, color='black')
plt.title("Distribution of Students by Stream")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6.2 Most Used AI Tools

# %%
# Most Used AI Tools
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, y='AI_Tools_Used', order=df['AI_Tools_Used'].value_counts().index, palette='coolwarm')
for p in ax.patches:
    count = int(p.get_width())
    ax.text(p.get_width() + 1, p.get_y() + p.get_height() / 2,
            str(count), ha='left', va='center', fontsize=8)
plt.title("Most Common AI Tools Used")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6.3 AI Usage vs Impact on Grades

# %%
# AI Usage vs. Grades
plt.figure(figsize=(14, 6))
sns.boxplot(data=df, x='Daily_Usage_Hours', y='Impact_on_Grades',hue='Daily_Usage_Hours', palette='Blues', legend=False)
plt.title("AI Usage vs Grade")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6.4 Trust in AI Tools

# %%
# Trust in AI Histogram
plt.figure(figsize=(10, 6))
df['Trust_in_AI_Tools'] = pd.to_numeric(df['Trust_in_AI_Tools'], errors='coerce')
ax = sns.histplot(df['Trust_in_AI_Tools'].dropna(), bins=10, kde=True, color='green')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2, height + 0.5, int(height),
                ha='center', va='bottom', fontsize=8, color='black')
plt.title("Trust in AI Distribution", fontsize=14)
plt.xlabel("Trust Level (1-5)")
plt.ylabel("Number of students")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6.5 Average Usage per Stream

# %%
# Average AI Usage by Stream
plt.figure(figsize=(10, 5))
avg_usage = df.groupby("Stream")['Daily_Usage_Hours'].mean().sort_values()
avg_usage.plot(kind='barh', color='purple')
for i, v in enumerate(avg_usage):
    plt.text(v, i, f"{v:.2f}", va='center')
plt.title("Average AI Usage per Stream", fontsize=14)
plt.xlabel("Hours per Week")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6.6 Correlation Heatmap

# %%
# Correlation Analysis (only numeric columns)
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Save cleaned dataset
cleaned_path = "ai_tool_usage_analysis_cleaned_file.csv"
df.to_csv(cleaned_path, index=False)
print(f"Cleaned dataset saved to: {cleaned_path}")
# Out:
# Cleaned dataset saved to: ai_tool_usage_analysis_cleaned_file.csv
